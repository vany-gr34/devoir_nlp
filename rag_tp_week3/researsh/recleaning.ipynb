# %%
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/datasets/kaoutharhamdan/routeee/export_final2(1).csv')

# %%
df.head(10)
# Out:
#    article_id                                    infraction_desc  amende_fixe  \
# 0           1  ال يجوز الي شخص ان يسوق مركبه ذات محرك او مجمو...          NaN
# 1           2  استثناء من احكام الماده االولي اعاله :\n - يجو...          NaN
# 2           5                                    من 13  بتاريخ 1          NaN
# 3           8                                    من 13  بتاريخ 1          NaN
# 4           9  يجب االدالء برخصه السياقه او بالوثيقه التي تحل...          NaN
# 5          10                                    من 13  بتاريخ 1          NaN
# 6          11                                    من 13  بتاريخ 1          NaN
# 7          12  يخضع وجوبا كل مترشح الختبارات امتحان الحصول عل...          NaN
# 8          13  اذا كان املترشح الختبارات امتحان الحصول علي رخ...          NaN
# 9          14                                           بتاريخ 1          NaN
#
#    amende_min  amende_max  points_retrait  emprisonnement  \
# ...

# %%
df = df.dropna(subset=["infraction_desc"])
df = df[~df["infraction_desc"].str.contains("من 13", na=False)]
df = df.reset_index(drop=True)

# %%
df['infraction_desc']
# Out:
# 0      ال يجوز الي شخص ان يسوق مركبه ذات محرك او مجمو...
# 1      استثناء من احكام الماده االولي اعاله :\n - يجو...
# 2      يجب االدالء برخصه السياقه او بالوثيقه التي تحل...
# 3      يخضع وجوبا كل مترشح الختبارات امتحان الحصول عل...
# 4      اذا كان املترشح الختبارات امتحان الحصول علي رخ...
#                              ...
# 197    من هذا القانون علي رخص السياقه املوقته املحصل ...
# 198    تعتبر رخصه السياقه النهاييه املسلمه قبل تاريخ ...
# 199    يجب علي اصحاب المركبات الخاضعه الحكام هذا القا...
# 200    يستمر ارباب مراكز الفحص التقني املزاولون نشاطه...
# 201    اعاله حيز التنفيذ وكيفيات تطبيقها  وذلك فيما ي...
# Name: infraction_desc, Length: 202, dtype: object

# %%
df.to_csv("cleaned_data.csv", index=False)
